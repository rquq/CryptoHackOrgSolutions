# %%
from sage.all import *
from Crypto.Util.number import inverse, long_to_bytes

from Crypto.Util.number import long_to_bytes

n = ...
ct = ...

# Define the polynomial ring over Z mod n
R = Zmod(n)
P.<x> = PolynomialRing(R)

# We want to find the roots of x^16 - ct = 0 mod n
f = x^16 - ct

print("Calculating all possible 16th roots...")
# This will calculate every single possible root natively
roots = f.roots(multiplicities=False)

print(f"Found {len(roots)} roots. Filtering for ASCII...")
for r in roots:
    try:
        # Convert each root back to bytes
        msg = long_to_bytes(int(r))
        
        # We only care about the root that contains human-readable text
        # Filter for standard ASCII characters
        if all(32 <= b <= 126 or b in [9, 10, 13] for b in msg):
            print("\n[+] SUCCESS! Flag found:")
            print(msg.decode('utf-8'))
    except:
        # Ignore roots that don't decode to bytes cleanly
        pass
# Out:
# Calculating all possible 16th roots...
# Found 8 roots. Filtering for ASCII...
#
# [+] SUCCESS! Flag found:
# Hey, if you are reading this maybe I didn't mess up my code too much. Phew. I really should play more CryptoHack before rushing to code stuff from scratch again. Here's the flag: crypto{m0dul4r_squ4r3_r00t}
